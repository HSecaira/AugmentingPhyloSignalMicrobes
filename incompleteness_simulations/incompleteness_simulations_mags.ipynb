# %% [markdown]
# # Simulate incomplete and contaminated bins using the EMP500 dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re
from scipy.stats import pmean
from collections import defaultdict
import seaborn as sns

# %% [markdown]
# Load data

# %%
def load_mapping(file):
    contigs = defaultdict(list)
    with open(file, 'r') as f:
        for line in f:
            l = line.strip().split(',')
            contig_id = l[0]
            prokka_id = l[1]
            contigs[contig_id].append(prokka_id)
    return dict(contigs)

# %%
def save_sampled_genes(file, genes):
    with open(file, 'w') as f:
        for gene in genes:
            f.write(f'{gene}\n')

# %% [markdown]
# ### Iterative approach: Given a threshold for the MAG incompleteness, randomly select a contig and iteratively remove ORFs until satisfying the threshold. If more contigs are necessary to satisfy the threshold, randomly select another contig and so on.

# %%
def sample_contigs_genes_v2(contigs, threshold, seed = 42):
    '''
    Remove ORFs sequentially from randomly sampled contig until incompleteness is satisfied.
    Here completeness refers to the total number of genes.
    Parameters
    ----------
        contigs : dict
            Contig names (keys) and list of prokka genes (values)
        threshold: float
            Completeness threshold--determines the number of genes to remove
    Returns
    -------
        genes_to_remove : list
            List of genes to be removed.
    '''
    # Fix seed for reproducibility
    rng = np.random.default_rng(seed)
    
    # Calculate total number of genes and the number of genes to remove
    num_genes_contig = sum(len(genes) for genes in contigs.values())
    num_genes_to_remove = int(threshold * num_genes_contig)
    
    # Flatten contig names
    contig_list = list(contigs.items())
    contig_indices = np.arange(len(contig_list))
    
    genes_to_remove = []
    # print(f'Number of genes to remove: {num_genes_to_remove} out of {num_genes_contig}')
    
    while num_genes_to_remove > 0 and len(contig_indices) > 0:
        # Randomly sample a contig
        sampled_contig_idx = rng.choice(contig_indices)
        contig_name, genes = contig_list[sampled_contig_idx]
        num_genes = len(genes)
        # print(f'\tSampled contig: {contig_name}, len: {num_genes}')
        
        if num_genes <= num_genes_to_remove:
            genes_to_remove.extend(genes)
            num_genes_to_remove -= num_genes
        else:
            for gene in genes:
                genes_to_remove.append(gene)
                num_genes_to_remove -= 1
                if num_genes_to_remove <= 0:
                    break
        
        # Remove the sampled contig index from the list
        contig_indices = contig_indices[contig_indices != sampled_contig_idx]
        # print(f'\tRemaining number of genes to remove: {num_genes_to_remove}')
        
    return genes_to_remove

# %% [markdown]
# **For all MAGs and thresholds, 10 replicates:**

# %%
replicates = np.arange(10)
thresholds = [0.05, 0.1, 0.2, 0.4]

# %% [markdown]
# Completeness

# %%
bins = np.loadtxt('./input_data/mags.txt', dtype = 'str')
bins.shape
# Out:
# (811,)

# %%
# %%time
for bi in bins:
    print(f'Bin: {bi}')
    # Load mapping between contigs and ORFs, from GFF file of prokka output
    contigs = load_mapping(f'./input_data/mapping/{bi}.mapping')
    # Replicates
    for rep in replicates:
        # Sample ORFs to remove according to threshold
        for threshold in thresholds:
            sampled = sample_contigs_genes_v2(contigs, threshold, rep)
            save_sampled_genes(f'./output_data/incompleteness/sampled_genes/{bi}_sample_contigs_genes_th_{threshold}_rep_{rep}.txt', sampled)
# Out:
# Bin: Bioreactor.Metabat.Bin.1
# Bin: Bioreactor.Metabat.Bin.10
# Bin: Bioreactor.Metabat.Bin.11
# Bin: Bioreactor.Metabat.Bin.14
# Bin: Bioreactor.Metabat.Bin.16
# Bin: Bioreactor.Metabat.Bin.19
# Bin: Bioreactor.Metabat.Bin.2
# Bin: Bioreactor.Metabat.Bin.20
# Bin: Bioreactor.Metabat.Bin.22
# Bin: Bioreactor.Metabat.Bin.23
# Bin: Bioreactor.Metabat.Bin.24
# Bin: Bioreactor.Metabat.Bin.28
# Bin: Bioreactor.Metabat.Bin.31
# Bin: Bioreactor.Metabat.Bin.32
# Bin: Bioreactor.Metabat.Bin.33
# Bin: Bioreactor.Metabat.Bin.34
# Bin: Bioreactor.Metabat.Bin.35
# Bin: Bioreactor.Metabat.Bin.39
# Bin: Bioreactor.Metabat.Bin.4
# Bin: Bioreactor.Metabat.Bin.40
# Bin: Bioreactor.Metabat.Bin.43
# Bin: Bioreactor.Metabat.Bin.44
# Bin: Bioreactor.Metabat.Bin.46
# Bin: Bioreactor.Metabat.Bin.47
# Bin: Bioreactor.Metabat.Bin.48
# Bin: Bioreactor.Metabat.Bin.49
# Bin: Bioreactor.Metabat.Bin.5
# Bin: Bioreactor.Metabat.Bin.51
# Bin: Bioreactor.Metabat.Bin.56
# Bin: Bioreactor.Metabat.Bin.58
# Bin: Bioreactor.Metabat.Bin.62
# Bin: Bioreactor.Metabat.Bin.63
# Bin: Bioreactor.Metabat.Bin.64
# Bin: Bioreactor.Metabat.Bin.65
# Bin: Bioreactor.Metabat.Bin.68
# Bin: Bioreactor.Metabat.Bin.7
# Bin: Bioreactor.Metabat.Bin.70
# Bin: Bioreactor.Metabat.Bin.73
# Bin: Bioreactor.Metabat.Bin.81
# Bin: Bioreactor.Metabat.Bin.87
# Bin: Bioreactor.Metabat.Bin.88
# Bin: Bioreactor.Metabat.Bin.9
# Bin: Bioreactor.Metabat.Bin.90
# Bin: Bird_feces.Metabat.Bin.1
# Bin: Bird_feces.Metabat.Bin.10
# Bin: Bird_feces.Metabat.Bin.100
# Bin: Bird_feces.Metabat.Bin.105
# Bin: Bird_feces.Metabat.Bin.106
# Bin: Bird_feces.Metabat.Bin.107
# Bin: Bird_feces.Metabat.Bin.111
# Bin: Bird_feces.Metabat.Bin.112
# Bin: Bird_feces.Metabat.Bin.114
# Bin: Bird_feces.Metabat.Bin.119
# Bin: Bird_feces.Metabat.Bin.124
# Bin: Bird_feces.Metabat.Bin.125
# Bin: Bird_feces.Metabat.Bin.126
# Bin: Bird_feces.Metabat.Bin.13
# Bin: Bird_feces.Metabat.Bin.136
# Bin: Bird_feces.Metabat.Bin.14
# Bin: Bird_feces.Metabat.Bin.146
# Bin: Bird_feces.Metabat.Bin.148
# Bin: Bird_feces.Metabat.Bin.15
# Bin: Bird_feces.Metabat.Bin.151
# Bin: Bird_feces.Metabat.Bin.153
# Bin: Bird_feces.Metabat.Bin.154
# Bin: Bird_feces.Metabat.Bin.157
# Bin: Bird_feces.Metabat.Bin.163
# Bin: Bird_feces.Metabat.Bin.18
# Bin: Bird_feces.Metabat.Bin.181
# Bin: Bird_feces.Metabat.Bin.184
# Bin: Bird_feces.Metabat.Bin.19
# Bin: Bird_feces.Metabat.Bin.192
# Bin: Bird_feces.Metabat.Bin.193
# Bin: Bird_feces.Metabat.Bin.194
# Bin: Bird_feces.Metabat.Bin.195
# Bin: Bird_feces.Metabat.Bin.198
# Bin: Bird_feces.Metabat.Bin.20
# Bin: Bird_feces.Metabat.Bin.208
# Bin: Bird_feces.Metabat.Bin.29
# Bin: Bird_feces.Metabat.Bin.3
# Bin: Bird_feces.Metabat.Bin.34
# Bin: Bird_feces.Metabat.Bin.36
# Bin: Bird_feces.Metabat.Bin.37
# Bin: Bird_feces.Metabat.Bin.41
# Bin: Bird_feces.Metabat.Bin.45
# Bin: Bird_feces.Metabat.Bin.47
# Bin: Bird_feces.Metabat.Bin.5
# Bin: Bird_feces.Metabat.Bin.52
# Bin: Bird_feces.Metabat.Bin.53
# Bin: Bird_feces.Metabat.Bin.54
# Bin: Bird_feces.Metabat.Bin.56
# Bin: Bird_feces.Metabat.Bin.58
# Bin: Bird_feces.Metabat.Bin.6
# Bin: Bird_feces.Metabat.Bin.60
# Bin: Bird_feces.Metabat.Bin.62
# Bin: Bird_feces.Metabat.Bin.63
# Bin: Bird_feces.Metabat.Bin.65
# Bin: Bird_feces.Metabat.Bin.66
# Bin: Bird_feces.Metabat.Bin.67
# Bin: Bird_feces.Metabat.Bin.68
# Bin: Bird_feces.Metabat.Bin.69
# Bin: Bird_feces.Metabat.Bin.7
# Bin: Bird_feces.Metabat.Bin.70
# Bin: Bird_feces.Metabat.Bin.75
# Bin: Bird_feces.Metabat.Bin.79
# Bin: Bird_feces.Metabat.Bin.80
# Bin: Bird_feces.Metabat.Bin.82
# Bin: Bird_feces.Metabat.Bin.85
# Bin: Bird_feces.Metabat.Bin.87
# Bin: Bird_feces.Metabat.Bin.88
# Bin: Bird_feces.Metabat.Bin.91
# Bin: Bird_feces.Metabat.Bin.92
# Bin: Bird_feces.Metabat.Bin.96
# Bin: Bird_feces.Metabat.Bin.97
# Bin: Bird_feces.Metabat.Bin.98
# Bin: Bird_feces.Metabat.Bin.99
# Bin: Centralia_soil.Metabat.Bin.1
# Bin: Centralia_soil.Metabat.Bin.12
# Bin: Centralia_soil.Metabat.Bin.18
# Bin: Centralia_soil.Metabat.Bin.2
# Bin: Centralia_soil.Metabat.Bin.23
# Bin: Centralia_soil.Metabat.Bin.3
# Bin: Centralia_soil.Metabat.Bin.36
# Bin: Centralia_soil.Metabat.Bin.5
# Bin: Centralia_soil.Metabat.Bin.8
# Bin: Centralia_soil.Metabat.Bin.9
# Bin: Chernobyl_vole.Metabat.Bin.100
# Bin: Chernobyl_vole.Metabat.Bin.106
# Bin: Chernobyl_vole.Metabat.Bin.113
# Bin: Chernobyl_vole.Metabat.Bin.117
# Bin: Chernobyl_vole.Metabat.Bin.118
# Bin: Chernobyl_vole.Metabat.Bin.12
# Bin: Chernobyl_vole.Metabat.Bin.121
# Bin: Chernobyl_vole.Metabat.Bin.122
# Bin: Chernobyl_vole.Metabat.Bin.125
# Bin: Chernobyl_vole.Metabat.Bin.130
# Bin: Chernobyl_vole.Metabat.Bin.14
# Bin: Chernobyl_vole.Metabat.Bin.140
# Bin: Chernobyl_vole.Metabat.Bin.145
# Bin: Chernobyl_vole.Metabat.Bin.164
# Bin: Chernobyl_vole.Metabat.Bin.171
# Bin: Chernobyl_vole.Metabat.Bin.175
# Bin: Chernobyl_vole.Metabat.Bin.182
# Bin: Chernobyl_vole.Metabat.Bin.194
# Bin: Chernobyl_vole.Metabat.Bin.22
# Bin: Chernobyl_vole.Metabat.Bin.26
# Bin: Chernobyl_vole.Metabat.Bin.30
# Bin: Chernobyl_vole.Metabat.Bin.31
# Bin: Chernobyl_vole.Metabat.Bin.32
# Bin: Chernobyl_vole.Metabat.Bin.43
# Bin: Chernobyl_vole.Metabat.Bin.45
# Bin: Chernobyl_vole.Metabat.Bin.5
# Bin: Chernobyl_vole.Metabat.Bin.50
# Bin: Chernobyl_vole.Metabat.Bin.52
# Bin: Chernobyl_vole.Metabat.Bin.55
# Bin: Chernobyl_vole.Metabat.Bin.63
# Bin: Chernobyl_vole.Metabat.Bin.69
# Bin: Chernobyl_vole.Metabat.Bin.7
# Bin: Chernobyl_vole.Metabat.Bin.75
# Bin: Chernobyl_vole.Metabat.Bin.78
# Bin: Chernobyl_vole.Metabat.Bin.79
# Bin: Chernobyl_vole.Metabat.Bin.81
# Bin: Chernobyl_vole.Metabat.Bin.88
# Bin: Chernobyl_vole.Metabat.Bin.90
# Bin: Chernobyl_vole.Metabat.Bin.99
# Bin: Coalmine.Metabat.Bin.1
# Bin: Coalmine.Metabat.Bin.10
# Bin: Coalmine.Metabat.Bin.20
# Bin: Coalmine.Metabat.Bin.3
# Bin: Coalmine.Metabat.Bin.6
# Bin: DeepC_Metabat_Bins.1
# Bin: DeepC_Metabat_Bins.11
# Bin: DeepC_Metabat_Bins.14
# Bin: DeepC_Metabat_Bins.15
# Bin: DeepC_Metabat_Bins.2
# Bin: DeepC_Metabat_Bins.22
# Bin: DeepC_Metabat_Bins.26
# Bin: DeepC_Metabat_Bins.29
# Bin: DeepC_Metabat_Bins.3
# Bin: DeepC_Metabat_Bins.30
# Bin: DeepC_Metabat_Bins.31
# Bin: DeepC_Metabat_Bins.32
# Bin: DeepC_Metabat_Bins.38
# Bin: DeepC_Metabat_Bins.43
# Bin: DeepC_Metabat_Bins.51
# Bin: DeepC_Metabat_Bins.6
# Bin: DeepC_Metabat_Bins.7
# Bin: Distel_shipworm.Metabat.Bin.1
# Bin: Distel_shipworm.Metabat.Bin.10
# Bin: Distel_shipworm.Metabat.Bin.14
# Bin: Distel_shipworm.Metabat.Bin.15
# Bin: Distel_shipworm.Metabat.Bin.18
# Bin: Distel_shipworm.Metabat.Bin.25
# Bin: Distel_shipworm.Metabat.Bin.27
# Bin: Distel_shipworm.Metabat.Bin.28
# Bin: Distel_shipworm.Metabat.Bin.30
# Bin: Distel_shipworm.Metabat.Bin.31
# Bin: Distel_shipworm.Metabat.Bin.32
# Bin: Distel_shipworm.Metabat.Bin.38
# Bin: Distel_shipworm.Metabat.Bin.4
# Bin: Distel_shipworm.Metabat.Bin.42
# Bin: Distel_shipworm.Metabat.Bin.43
# Bin: Distel_shipworm.Metabat.Bin.44
# Bin: Distel_shipworm.Metabat.Bin.47
# Bin: Distel_shipworm.Metabat.Bin.56
# Bin: Distel_shipworm.Metabat.Bin.59
# Bin: Distel_shipworm.Metabat.Bin.6
# Bin: Distel_shipworm.Metabat.Bin.61
# Bin: Distel_shipworm.Metabat.Bin.62
# Bin: Distel_shipworm.Metabat.Bin.66
# Bin: Distel_shipworm.Metabat.Bin.67
# Bin: Distel_shipworm.Metabat.Bin.7
# Bin: Distel_shipworm.Metabat.Bin.72
# Bin: Distel_shipworm.Metabat.Bin.77
# Bin: Distel_shipworm.Metabat.Bin.79
# Bin: Distel_shipworm.Metabat.Bin.82
# Bin: Distel_shipworm.Metabat.Bin.88
# Bin: Distel_shipworm.Metabat.Bin.89
# Bin: Distel_shipworm.Metabat.Bin.9
# Bin: Fish_gut.Metabat.Bin.1
# Bin: Fish_gut.Metabat.Bin.13
# Bin: Fish_gut.Metabat.Bin.24
# Bin: Fish_gut.Metabat.Bin.32
# Bin: Fish_gut.Metabat.Bin.35
# Bin: Fish_gut.Metabat.Bin.37
# Bin: Fish_gut.Metabat.Bin.43
# Bin: Fish_gut.Metabat.Bin.45
# Bin: Fish_gut.Metabat.Bin.5
# Bin: Fish_gut.Metabat.Bin.55
# Bin: Fish_gut.Metabat.Bin.58
# Bin: Insect.Metabat.Bin.10
# Bin: Insect.Metabat.Bin.118
# Bin: Insect.Metabat.Bin.119
# Bin: Insect.Metabat.Bin.121
# Bin: Insect.Metabat.Bin.125
# Bin: Insect.Metabat.Bin.129
# Bin: Insect.Metabat.Bin.167
# Bin: Insect.Metabat.Bin.22
# Bin: Insect.Metabat.Bin.24
# Bin: Insect.Metabat.Bin.25
# Bin: Insect.Metabat.Bin.29
# Bin: Insect.Metabat.Bin.30
# Bin: Insect.Metabat.Bin.33
# Bin: Insect.Metabat.Bin.34
# Bin: Insect.Metabat.Bin.42
# Bin: Insect.Metabat.Bin.49
# Bin: Insect.Metabat.Bin.51
# Bin: Insect.Metabat.Bin.54
# Bin: Insect.Metabat.Bin.57
# Bin: Insect.Metabat.Bin.60
# Bin: Insect.Metabat.Bin.65
# Bin: Insect.Metabat.Bin.68
# Bin: Insect.Metabat.Bin.72
# Bin: Insect.Metabat.Bin.78
# Bin: Insect.Metabat.Bin.9
# Bin: Jensen_Benthic.Metabat.Bin.3
# Bin: Jensen_Benthic.Metabat.Bin.5
# Bin: Lake_sediment.Metabat.Bin.12
# Bin: Lake_sediment.Metabat.Bin.15
# Bin: Lake_sediment.Metabat.Bin.3
# Bin: Lake_sediment.Metabat.Bin.4
# Bin: Lake_sediment.Metabat.Bin.6
# Bin: Lichen.Metabat.Bin.11
# Bin: Lichen.Metabat.Bin.19
# Bin: Lichen.Metabat.Bin.29
# Bin: Marsh.Metabat.Bin.10
# Bin: Marsh.Metabat.Bin.12
# Bin: Marsh.Metabat.Bin.35
# Bin: Marsh.Metabat.Bin.7
# Bin: Mayer_watershed.Metabat.Bin.5
# Bin: Minich_livetsock.Metabat.Bin.1
# Bin: Minich_livetsock.Metabat.Bin.10
# Bin: Minich_livetsock.Metabat.Bin.100
# Bin: Minich_livetsock.Metabat.Bin.102
# Bin: Minich_livetsock.Metabat.Bin.106
# Bin: Minich_livetsock.Metabat.Bin.107
# Bin: Minich_livetsock.Metabat.Bin.11
# Bin: Minich_livetsock.Metabat.Bin.117
# Bin: Minich_livetsock.Metabat.Bin.14
# Bin: Minich_livetsock.Metabat.Bin.17
# Bin: Minich_livetsock.Metabat.Bin.19
# Bin: Minich_livetsock.Metabat.Bin.2
# Bin: Minich_livetsock.Metabat.Bin.23
# Bin: Minich_livetsock.Metabat.Bin.26
# Bin: Minich_livetsock.Metabat.Bin.27
# Bin: Minich_livetsock.Metabat.Bin.29
# Bin: Minich_livetsock.Metabat.Bin.3
# Bin: Minich_livetsock.Metabat.Bin.30
# Bin: Minich_livetsock.Metabat.Bin.35
# Bin: Minich_livetsock.Metabat.Bin.36
# Bin: Minich_livetsock.Metabat.Bin.4
# Bin: Minich_livetsock.Metabat.Bin.53
# Bin: Minich_livetsock.Metabat.Bin.54
# Bin: Minich_livetsock.Metabat.Bin.55
# Bin: Minich_livetsock.Metabat.Bin.57
# Bin: Minich_livetsock.Metabat.Bin.59
# Bin: Minich_livetsock.Metabat.Bin.61
# Bin: Minich_livetsock.Metabat.Bin.63
# Bin: Minich_livetsock.Metabat.Bin.66
# Bin: Minich_livetsock.Metabat.Bin.68
# Bin: Minich_livetsock.Metabat.Bin.72
# Bin: Minich_livetsock.Metabat.Bin.77
# Bin: Minich_livetsock.Metabat.Bin.78
# Bin: Minich_livetsock.Metabat.Bin.8
# Bin: Minich_livetsock.Metabat.Bin.81
# Bin: Minich_livetsock.Metabat.Bin.84
# Bin: Minich_livetsock.Metabat.Bin.9
# Bin: Minich_livetsock.Metabat.Bin.94
# Bin: Myrold59_soil.Metabat.Bin.1
# Bin: Myrold59_soil.Metabat.Bin.10
# Bin: Myrold59_soil.Metabat.Bin.11
# Bin: Myrold59_soil.Metabat.Bin.12
# Bin: Myrold59_soil.Metabat.Bin.13
# Bin: Myrold59_soil.Metabat.Bin.14
# Bin: Myrold59_soil.Metabat.Bin.15
# Bin: Myrold59_soil.Metabat.Bin.16
# Bin: Myrold59_soil.Metabat.Bin.17
# Bin: Myrold59_soil.Metabat.Bin.18
# Bin: Myrold59_soil.Metabat.Bin.19
# Bin: Myrold59_soil.Metabat.Bin.2
# Bin: Myrold59_soil.Metabat.Bin.20
# Bin: Myrold59_soil.Metabat.Bin.21
# Bin: Myrold59_soil.Metabat.Bin.22
# Bin: Myrold59_soil.Metabat.Bin.3
# Bin: Myrold59_soil.Metabat.Bin.4
# Bin: Myrold59_soil.Metabat.Bin.5
# Bin: Myrold59_soil.Metabat.Bin.6
# Bin: Myrold59_soil.Metabat.Bin.7
# Bin: Myrold59_soil.Metabat.Bin.8
# Bin: Myrold59_soil.Metabat.Bin.9
# Bin: Permafrost.Metabat.Bin.108
# Bin: Permafrost.Metabat.Bin.18
# Bin: Permafrost.Metabat.Bin.23
# Bin: Permafrost.Metabat.Bin.3
# Bin: Permafrost.Metabat.Bin.40
# Bin: Permafrost.Metabat.Bin.8
# Bin: Permafrost.Metabat.Bin.81
# Bin: Permafrost.Metabat.Bin.91
# Bin: Pitcher_fluids.Metabat.Bin.1
# Bin: Pitcher_fluids.Metabat.Bin.10
# Bin: Pitcher_fluids.Metabat.Bin.13
# Bin: Pitcher_fluids.Metabat.Bin.14
# Bin: Pitcher_fluids.Metabat.Bin.18
# Bin: Pitcher_fluids.Metabat.Bin.19
# Bin: Pitcher_fluids.Metabat.Bin.2
# Bin: Pitcher_fluids.Metabat.Bin.21
# Bin: Pitcher_fluids.Metabat.Bin.24
# Bin: Pitcher_fluids.Metabat.Bin.25
# Bin: Pitcher_fluids.Metabat.Bin.32
# Bin: Pitcher_fluids.Metabat.Bin.4
# Bin: Pitcher_fluids.Metabat.Bin.40
# Bin: Pitcher_fluids.Metabat.Bin.5
# Bin: Pitcher_fluids.Metabat.Bin.6
# Bin: Pitcher_fluids.Metabat.Bin.68
# Bin: Pitcher_fluids.Metabat.Bin.69
# Bin: Pitcher_fluids.Metabat.Bin.74
# Bin: Rohwer85_tundra.Metabat.Bin.1
# Bin: Rohwer85_tundra.Metabat.Bin.10
# Bin: Rohwer85_tundra.Metabat.Bin.2
# Bin: Rohwer85_tundra.Metabat.Bin.3
# Bin: Rohwer85_tundra.Metabat.Bin.4
# Bin: Rohwer85_tundra.Metabat.Bin.5
# Bin: Rohwer85_tundra.Metabat.Bin.6
# Bin: Rohwer85_tundra.Metabat.Bin.7
# Bin: Rohwer85_tundra.Metabat.Bin.8
# Bin: Rohwer85_tundra.Metabat.Bin.9
# Bin: Rumen.Metabat.Bin.1
# Bin: Rumen.Metabat.Bin.10
# Bin: Rumen.Metabat.Bin.11
# Bin: Rumen.Metabat.Bin.15
# Bin: Rumen.Metabat.Bin.19
# Bin: Rumen.Metabat.Bin.20
# Bin: Rumen.Metabat.Bin.21
# Bin: Rumen.Metabat.Bin.23
# Bin: Rumen.Metabat.Bin.25
# Bin: Rumen.Metabat.Bin.29
# Bin: Rumen.Metabat.Bin.32
# Bin: Rumen.Metabat.Bin.33
# Bin: Rumen.Metabat.Bin.35
# Bin: Rumen.Metabat.Bin.37
# Bin: Rumen.Metabat.Bin.4
# Bin: Rumen.Metabat.Bin.40
# Bin: Rumen.Metabat.Bin.42
# Bin: Rumen.Metabat.Bin.45
# Bin: Rumen.Metabat.Bin.49
# Bin: Rumen.Metabat.Bin.5
# Bin: Rumen.Metabat.Bin.50
# Bin: Rumen.Metabat.Bin.51
# Bin: Rumen.Metabat.Bin.52
# Bin: Rumen.Metabat.Bin.53
# Bin: Rumen.Metabat.Bin.54
# Bin: Rumen.Metabat.Bin.55
# Bin: Rumen.Metabat.Bin.56
# Bin: Rumen.Metabat.Bin.57
# Bin: Rumen.Metabat.Bin.60
# Bin: Rumen.Metabat.Bin.61
# Bin: Rumen.Metabat.Bin.64
# Bin: Rumen.Metabat.Bin.67
# Bin: Rumen.Metabat.Bin.68
# Bin: Rumen.Metabat.Bin.73
# Bin: Rumen.Metabat.Bin.76
# Bin: Rumen.Metabat.Bin.78
# Bin: Rumen.Metabat.Bin.82
# Bin: Rumen.Metabat.Bin.84
# Bin: Rumen.Metabat.Bin.86
# Bin: Rumen.Metabat.Bin.88
# Bin: Rumen.Metabat.Bin.89
# Bin: Rumen.Metabat.Bin.9
# Bin: Rumen.Metabat.Bin.94
# Bin: SW.Metabat.Bin.10
# Bin: SW.Metabat.Bin.107
# Bin: SW.Metabat.Bin.127
# Bin: SW.Metabat.Bin.133
# Bin: SW.Metabat.Bin.145
# Bin: SW.Metabat.Bin.159
# Bin: SW.Metabat.Bin.189
# Bin: SW.Metabat.Bin.230
# Bin: SW.Metabat.Bin.237
# Bin: SW.Metabat.Bin.241
# Bin: SW.Metabat.Bin.249
# Bin: SW.Metabat.Bin.28
# Bin: SW.Metabat.Bin.3
# Bin: SW.Metabat.Bin.40
# Bin: SW.Metabat.Bin.63
# Bin: SW.Metabat.Bin.76
# Bin: SW.Metabat.Bin.97
# Bin: SaltMarsh.Metabat.Bin.1
# Bin: SaltMarsh.Metabat.Bin.10
# Bin: SaltMarsh.Metabat.Bin.11
# Bin: SaltMarsh.Metabat.Bin.14
# Bin: SaltMarsh.Metabat.Bin.16
# Bin: SaltMarsh.Metabat.Bin.19
# Bin: SaltMarsh.Metabat.Bin.2
# Bin: SaltMarsh.Metabat.Bin.20
# Bin: SaltMarsh.Metabat.Bin.22
# Bin: SaltMarsh.Metabat.Bin.23
# Bin: SaltMarsh.Metabat.Bin.24
# Bin: SaltMarsh.Metabat.Bin.28
# Bin: SaltMarsh.Metabat.Bin.31
# Bin: SaltMarsh.Metabat.Bin.32
# Bin: SaltMarsh.Metabat.Bin.33
# Bin: SaltMarsh.Metabat.Bin.34
# Bin: SaltMarsh.Metabat.Bin.35
# Bin: SaltMarsh.Metabat.Bin.39
# Bin: SaltMarsh.Metabat.Bin.4
# Bin: SaltMarsh.Metabat.Bin.40
# Bin: SaltMarsh.Metabat.Bin.43
# Bin: SaltMarsh.Metabat.Bin.44
# Bin: SaltMarsh.Metabat.Bin.46
# Bin: SaltMarsh.Metabat.Bin.47
# Bin: SaltMarsh.Metabat.Bin.48
# Bin: SaltMarsh.Metabat.Bin.49
# Bin: SaltMarsh.Metabat.Bin.5
# Bin: SaltMarsh.Metabat.Bin.51
# Bin: SaltMarsh.Metabat.Bin.54
# Bin: SaltMarsh.Metabat.Bin.56
# Bin: SaltMarsh.Metabat.Bin.58
# Bin: SaltMarsh.Metabat.Bin.63
# Bin: SaltMarsh.Metabat.Bin.64
# Bin: SaltMarsh.Metabat.Bin.65
# Bin: SaltMarsh.Metabat.Bin.68
# Bin: SaltMarsh.Metabat.Bin.7
# Bin: SaltMarsh.Metabat.Bin.70
# Bin: SaltMarsh.Metabat.Bin.73
# Bin: SaltMarsh.Metabat.Bin.9
# Bin: Seawater.Metabat.Bin.10
# Bin: Seawater.Metabat.Bin.110
# Bin: Seawater.Metabat.Bin.125
# Bin: Seawater.Metabat.Bin.129
# Bin: Seawater.Metabat.Bin.13
# Bin: Seawater.Metabat.Bin.136
# Bin: Seawater.Metabat.Bin.141
# Bin: Seawater.Metabat.Bin.143
# Bin: Seawater.Metabat.Bin.15
# Bin: Seawater.Metabat.Bin.150
# Bin: Seawater.Metabat.Bin.178
# Bin: Seawater.Metabat.Bin.18
# Bin: Seawater.Metabat.Bin.189
# Bin: Seawater.Metabat.Bin.199
# Bin: Seawater.Metabat.Bin.234
# Bin: Seawater.Metabat.Bin.240
# Bin: Seawater.Metabat.Bin.245
# Bin: Seawater.Metabat.Bin.249
# Bin: Seawater.Metabat.Bin.263
# Bin: Seawater.Metabat.Bin.27
# Bin: Seawater.Metabat.Bin.285
# Bin: Seawater.Metabat.Bin.31
# Bin: Seawater.Metabat.Bin.33
# Bin: Seawater.Metabat.Bin.63
# Bin: Seawater.Metabat.Bin.70
# Bin: Seawater.Metabat.Bin.78
# Bin: Seawater.Metabat.Bin.79
# Bin: Seawater.Metabat.Bin.8
# Bin: Seawater.Metabat.Bin.9
# Bin: Seawater.Metabat.Bin.93
# Bin: Seedorf_soil.Metabat.Bin.1
# Bin: Seedorf_soil.Metabat.Bin.2
# Bin: Seedorf_soil.Metabat.Bin.6
# Bin: Song75_aquatic.Metabat.Bin.1
# Bin: Song75_aquatic.Metabat.Bin.10
# Bin: Song75_aquatic.Metabat.Bin.13
# Bin: Song75_aquatic.Metabat.Bin.15
# Bin: Song75_aquatic.Metabat.Bin.17
# Bin: Song75_aquatic.Metabat.Bin.18
# Bin: Song75_aquatic.Metabat.Bin.2
# Bin: Song75_aquatic.Metabat.Bin.21
# Bin: Song75_aquatic.Metabat.Bin.23
# Bin: Song75_aquatic.Metabat.Bin.25
# Bin: Song75_aquatic.Metabat.Bin.28
# Bin: Song75_aquatic.Metabat.Bin.3
# Bin: Song75_aquatic.Metabat.Bin.30
# Bin: Song75_aquatic.Metabat.Bin.31
# Bin: Song75_aquatic.Metabat.Bin.32
# Bin: Song75_aquatic.Metabat.Bin.33
# Bin: Song75_aquatic.Metabat.Bin.34
# Bin: Song75_aquatic.Metabat.Bin.36
# Bin: Song75_aquatic.Metabat.Bin.38
# Bin: Song75_aquatic.Metabat.Bin.4
# Bin: Song75_aquatic.Metabat.Bin.41
# Bin: Song75_aquatic.Metabat.Bin.44
# Bin: Song75_aquatic.Metabat.Bin.46
# Bin: Song75_aquatic.Metabat.Bin.50
# Bin: Song75_aquatic.Metabat.Bin.51
# Bin: Song75_aquatic.Metabat.Bin.52
# Bin: Song75_aquatic.Metabat.Bin.59
# Bin: Song75_aquatic.Metabat.Bin.6
# Bin: Song75_aquatic.Metabat.Bin.68
# Bin: Song75_aquatic.Metabat.Bin.69
# Bin: Song75_aquatic.Metabat.Bin.7
# Bin: Song75_aquatic.Metabat.Bin.76
# Bin: Song75_aquatic.Metabat.Bin.8
# Bin: Song75_aquatic.Metabat.Bin.9
# Bin: Song_Terr.Metabat.Bin.1
# Bin: Song_Terr.Metabat.Bin.10
# Bin: Song_Terr.Metabat.Bin.101
# Bin: Song_Terr.Metabat.Bin.104
# Bin: Song_Terr.Metabat.Bin.105
# Bin: Song_Terr.Metabat.Bin.11
# Bin: Song_Terr.Metabat.Bin.112
# Bin: Song_Terr.Metabat.Bin.113
# Bin: Song_Terr.Metabat.Bin.115
# Bin: Song_Terr.Metabat.Bin.118
# Bin: Song_Terr.Metabat.Bin.12
# Bin: Song_Terr.Metabat.Bin.120
# Bin: Song_Terr.Metabat.Bin.122
# Bin: Song_Terr.Metabat.Bin.124
# Bin: Song_Terr.Metabat.Bin.126
# Bin: Song_Terr.Metabat.Bin.13
# Bin: Song_Terr.Metabat.Bin.131
# Bin: Song_Terr.Metabat.Bin.136
# Bin: Song_Terr.Metabat.Bin.137
# Bin: Song_Terr.Metabat.Bin.14
# Bin: Song_Terr.Metabat.Bin.144
# Bin: Song_Terr.Metabat.Bin.145
# Bin: Song_Terr.Metabat.Bin.148
# Bin: Song_Terr.Metabat.Bin.15
# Bin: Song_Terr.Metabat.Bin.158
# Bin: Song_Terr.Metabat.Bin.160
# Bin: Song_Terr.Metabat.Bin.163
# Bin: Song_Terr.Metabat.Bin.165
# Bin: Song_Terr.Metabat.Bin.171
# Bin: Song_Terr.Metabat.Bin.172
# Bin: Song_Terr.Metabat.Bin.174
# Bin: Song_Terr.Metabat.Bin.175
# Bin: Song_Terr.Metabat.Bin.176
# Bin: Song_Terr.Metabat.Bin.177
# Bin: Song_Terr.Metabat.Bin.179
# Bin: Song_Terr.Metabat.Bin.18
# Bin: Song_Terr.Metabat.Bin.181
# Bin: Song_Terr.Metabat.Bin.19
# Bin: Song_Terr.Metabat.Bin.192
# Bin: Song_Terr.Metabat.Bin.194
# Bin: Song_Terr.Metabat.Bin.20
# Bin: Song_Terr.Metabat.Bin.201
# Bin: Song_Terr.Metabat.Bin.205
# Bin: Song_Terr.Metabat.Bin.207
# Bin: Song_Terr.Metabat.Bin.209
# Bin: Song_Terr.Metabat.Bin.217
# Bin: Song_Terr.Metabat.Bin.22
# Bin: Song_Terr.Metabat.Bin.220
# Bin: Song_Terr.Metabat.Bin.222
# Bin: Song_Terr.Metabat.Bin.23
# Bin: Song_Terr.Metabat.Bin.235
# Bin: Song_Terr.Metabat.Bin.237
# Bin: Song_Terr.Metabat.Bin.239
# Bin: Song_Terr.Metabat.Bin.241
# Bin: Song_Terr.Metabat.Bin.245
# Bin: Song_Terr.Metabat.Bin.247
# Bin: Song_Terr.Metabat.Bin.248
# Bin: Song_Terr.Metabat.Bin.251
# Bin: Song_Terr.Metabat.Bin.254
# Bin: Song_Terr.Metabat.Bin.255
# Bin: Song_Terr.Metabat.Bin.258
# Bin: Song_Terr.Metabat.Bin.259
# Bin: Song_Terr.Metabat.Bin.26
# Bin: Song_Terr.Metabat.Bin.262
# Bin: Song_Terr.Metabat.Bin.264
# Bin: Song_Terr.Metabat.Bin.265
# Bin: Song_Terr.Metabat.Bin.269
# Bin: Song_Terr.Metabat.Bin.27
# Bin: Song_Terr.Metabat.Bin.271
# Bin: Song_Terr.Metabat.Bin.279
# Bin: Song_Terr.Metabat.Bin.28
# Bin: Song_Terr.Metabat.Bin.296
# Bin: Song_Terr.Metabat.Bin.297
# Bin: Song_Terr.Metabat.Bin.3
# Bin: Song_Terr.Metabat.Bin.306
# Bin: Song_Terr.Metabat.Bin.308
# Bin: Song_Terr.Metabat.Bin.310
# Bin: Song_Terr.Metabat.Bin.319
# Bin: Song_Terr.Metabat.Bin.320
# Bin: Song_Terr.Metabat.Bin.323
# Bin: Song_Terr.Metabat.Bin.33
# Bin: Song_Terr.Metabat.Bin.338
# Bin: Song_Terr.Metabat.Bin.343
# Bin: Song_Terr.Metabat.Bin.344
# Bin: Song_Terr.Metabat.Bin.345
# Bin: Song_Terr.Metabat.Bin.349
# Bin: Song_Terr.Metabat.Bin.351
# Bin: Song_Terr.Metabat.Bin.354
# Bin: Song_Terr.Metabat.Bin.357
# Bin: Song_Terr.Metabat.Bin.36
# Bin: Song_Terr.Metabat.Bin.361
# Bin: Song_Terr.Metabat.Bin.363
# Bin: Song_Terr.Metabat.Bin.368
# Bin: Song_Terr.Metabat.Bin.383
# Bin: Song_Terr.Metabat.Bin.388
# Bin: Song_Terr.Metabat.Bin.39
# Bin: Song_Terr.Metabat.Bin.390
# Bin: Song_Terr.Metabat.Bin.391
# Bin: Song_Terr.Metabat.Bin.4
# Bin: Song_Terr.Metabat.Bin.402
# Bin: Song_Terr.Metabat.Bin.407
# Bin: Song_Terr.Metabat.Bin.41
# Bin: Song_Terr.Metabat.Bin.417
# Bin: Song_Terr.Metabat.Bin.427
# Bin: Song_Terr.Metabat.Bin.428
# Bin: Song_Terr.Metabat.Bin.434
# Bin: Song_Terr.Metabat.Bin.435
# Bin: Song_Terr.Metabat.Bin.443
# Bin: Song_Terr.Metabat.Bin.445
# Bin: Song_Terr.Metabat.Bin.447
# Bin: Song_Terr.Metabat.Bin.449
# Bin: Song_Terr.Metabat.Bin.45
# Bin: Song_Terr.Metabat.Bin.452
# Bin: Song_Terr.Metabat.Bin.455
# Bin: Song_Terr.Metabat.Bin.456
# Bin: Song_Terr.Metabat.Bin.457
# Bin: Song_Terr.Metabat.Bin.46
# Bin: Song_Terr.Metabat.Bin.463
# Bin: Song_Terr.Metabat.Bin.475
# Bin: Song_Terr.Metabat.Bin.478
# Bin: Song_Terr.Metabat.Bin.479
# Bin: Song_Terr.Metabat.Bin.486
# Bin: Song_Terr.Metabat.Bin.489
# Bin: Song_Terr.Metabat.Bin.490
# Bin: Song_Terr.Metabat.Bin.5
# Bin: Song_Terr.Metabat.Bin.514
# Bin: Song_Terr.Metabat.Bin.517
# Bin: Song_Terr.Metabat.Bin.518
# Bin: Song_Terr.Metabat.Bin.519
# Bin: Song_Terr.Metabat.Bin.529
# Bin: Song_Terr.Metabat.Bin.53
# Bin: Song_Terr.Metabat.Bin.532
# Bin: Song_Terr.Metabat.Bin.534
# Bin: Song_Terr.Metabat.Bin.54
# Bin: Song_Terr.Metabat.Bin.540
# Bin: Song_Terr.Metabat.Bin.562
# Bin: Song_Terr.Metabat.Bin.566
# Bin: Song_Terr.Metabat.Bin.57
# Bin: Song_Terr.Metabat.Bin.574
# Bin: Song_Terr.Metabat.Bin.58
# Bin: Song_Terr.Metabat.Bin.580
# Bin: Song_Terr.Metabat.Bin.582
# Bin: Song_Terr.Metabat.Bin.59
# Bin: Song_Terr.Metabat.Bin.595
# Bin: Song_Terr.Metabat.Bin.6
# Bin: Song_Terr.Metabat.Bin.623
# Bin: Song_Terr.Metabat.Bin.636
# Bin: Song_Terr.Metabat.Bin.64
# Bin: Song_Terr.Metabat.Bin.66
# Bin: Song_Terr.Metabat.Bin.68
# Bin: Song_Terr.Metabat.Bin.69
# Bin: Song_Terr.Metabat.Bin.70
# Bin: Song_Terr.Metabat.Bin.79
# Bin: Song_Terr.Metabat.Bin.8
# Bin: Song_Terr.Metabat.Bin.80
# Bin: Song_Terr.Metabat.Bin.81
# Bin: Song_Terr.Metabat.Bin.82
# Bin: Song_Terr.Metabat.Bin.83
# Bin: Song_Terr.Metabat.Bin.85
# Bin: Song_Terr.Metabat.Bin.87
# Bin: Song_Terr.Metabat.Bin.89
# Bin: Song_Terr.Metabat.Bin.90
# Bin: Song_Terr.Metabat.Bin.91
# Bin: Song_Terr.Metabat.Bin.95
# Bin: Song_Terr.Metabat.Bin.96
# Bin: Song_Terr.Metabat.Bin.98
# Bin: Song_Terr.Metabat.Bin.99
# Bin: Sponges.Metabat.Bin.1
# Bin: Sponges.Metabat.Bin.10
# Bin: Sponges.Metabat.Bin.109
# Bin: Sponges.Metabat.Bin.11
# Bin: Sponges.Metabat.Bin.114
# Bin: Sponges.Metabat.Bin.116
# Bin: Sponges.Metabat.Bin.12
# Bin: Sponges.Metabat.Bin.122
# Bin: Sponges.Metabat.Bin.139
# Bin: Sponges.Metabat.Bin.141
# Bin: Sponges.Metabat.Bin.149
# Bin: Sponges.Metabat.Bin.152
# Bin: Sponges.Metabat.Bin.163
# Bin: Sponges.Metabat.Bin.17
# Bin: Sponges.Metabat.Bin.185
# Bin: Sponges.Metabat.Bin.19
# Bin: Sponges.Metabat.Bin.192
# Bin: Sponges.Metabat.Bin.195
# Bin: Sponges.Metabat.Bin.199
# Bin: Sponges.Metabat.Bin.20
# Bin: Sponges.Metabat.Bin.203
# Bin: Sponges.Metabat.Bin.21
# Bin: Sponges.Metabat.Bin.22
# Bin: Sponges.Metabat.Bin.225
# Bin: Sponges.Metabat.Bin.243
# Bin: Sponges.Metabat.Bin.25
# Bin: Sponges.Metabat.Bin.250
# Bin: Sponges.Metabat.Bin.255
# Bin: Sponges.Metabat.Bin.269
# Bin: Sponges.Metabat.Bin.3
# Bin: Sponges.Metabat.Bin.35
# Bin: Sponges.Metabat.Bin.40
# Bin: Sponges.Metabat.Bin.42
# Bin: Sponges.Metabat.Bin.44
# Bin: Sponges.Metabat.Bin.45
# Bin: Sponges.Metabat.Bin.5
# Bin: Sponges.Metabat.Bin.51
# Bin: Sponges.Metabat.Bin.52
# Bin: Sponges.Metabat.Bin.59
# Bin: Sponges.Metabat.Bin.60
# Bin: Sponges.Metabat.Bin.65
# Bin: Sponges.Metabat.Bin.67
# Bin: Sponges.Metabat.Bin.68
# Bin: Sponges.Metabat.Bin.79
# Bin: Sponges.Metabat.Bin.8
# Bin: Sponges.Metabat.Bin.83
# Bin: Sponges.Metabat.Bin.88
# Bin: Sponges.Metabat.Bin.9
# Bin: Sponges.Metabat.Bin.93
# Bin: Sponges.Metabat.Bin.99
# Bin: Steppe.Metabat.Bin.3
# Bin: Tempsoil.Metabat.Bin.1
# Bin: Tempsoil.Metabat.Bin.11
# Bin: Tempsoil.Metabat.Bin.12
# Bin: Tempsoil.Metabat.Bin.13
# Bin: Tempsoil.Metabat.Bin.21
# Bin: Tempsoil.Metabat.Bin.28
# Bin: Tempsoil.Metabat.Bin.36
# Bin: Tempsoil.Metabat.Bin.7
# Bin: Tempsoil.Metabat.Bin.9
# Bin: Volcanic.Metabat.Bin.1
# Bin: Volcanic.Metabat.Bin.10
# Bin: Volcanic.Metabat.Bin.100
# Bin: Volcanic.Metabat.Bin.11
# Bin: Volcanic.Metabat.Bin.110
# Bin: Volcanic.Metabat.Bin.14
# Bin: Volcanic.Metabat.Bin.15
# Bin: Volcanic.Metabat.Bin.16
# Bin: Volcanic.Metabat.Bin.17
# Bin: Volcanic.Metabat.Bin.18
# Bin: Volcanic.Metabat.Bin.2
# Bin: Volcanic.Metabat.Bin.20
# Bin: Volcanic.Metabat.Bin.21
# Bin: Volcanic.Metabat.Bin.22
# Bin: Volcanic.Metabat.Bin.23
# Bin: Volcanic.Metabat.Bin.26
# Bin: Volcanic.Metabat.Bin.28
# Bin: Volcanic.Metabat.Bin.3
# Bin: Volcanic.Metabat.Bin.31
# Bin: Volcanic.Metabat.Bin.34
# Bin: Volcanic.Metabat.Bin.35
# Bin: Volcanic.Metabat.Bin.36
# Bin: Volcanic.Metabat.Bin.39
# Bin: Volcanic.Metabat.Bin.4
# Bin: Volcanic.Metabat.Bin.40
# Bin: Volcanic.Metabat.Bin.42
# Bin: Volcanic.Metabat.Bin.54
# Bin: Volcanic.Metabat.Bin.58
# Bin: Volcanic.Metabat.Bin.6
# Bin: Volcanic.Metabat.Bin.60
# Bin: Volcanic.Metabat.Bin.7
# Bin: Volcanic.Metabat.Bin.74
# Bin: Volcanic.Metabat.Bin.8
# Bin: Volcanic.Metabat.Bin.86
# Bin: Volcanic.Metabat.Bin.88
# Bin: Volcanic.Metabat.Bin.9
# Bin: Volcanic.Metabat.Bin.97
# Bin: Whale.Metabat.Bin.124
# Bin: Whale.Metabat.Bin.13
# Bin: Whale.Metabat.Bin.130
# Bin: Whale.Metabat.Bin.145
# Bin: Whale.Metabat.Bin.16
# Bin: Whale.Metabat.Bin.24
# Bin: Whale.Metabat.Bin.28
# Bin: Whale.Metabat.Bin.3
# Bin: Whale.Metabat.Bin.4
# Bin: Whale.Metabat.Bin.69
# Bin: Zaneveld_reef.Metabat.Bin.12
# Bin: Zaneveld_reef.Metabat.Bin.25
# Bin: Zaneveld_reef.Metabat.Bin.4
# Bin: Zaneveld_reef.Metabat.Bin.5
# Bin: Zaneveld_reef.Metabat.Bin.6
# CPU times: user 35.7 s, sys: 4.1 s, total: 39.8 s
# Wall time: 41.3 s
